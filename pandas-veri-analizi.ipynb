# %%
import glob
import pandas as pd
path = r'/kaggle/input/titanic'
filenames = glob.glob(path + "/*.csv")
titanic = pd.DataFrame()
for f in filenames:
    df = pd.read_csv(f)
    titanic = titanic._append(df, ignore_index = True, sort = True)

# %%
titanic = titanic.fillna(0) 
titanic = titanic.replace([float('inf'), float('-inf')], 0 )
df_cleaned = df.dropna()

# %%
titanic.head(10)
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0     0        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0     0        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0     0        S   8.0500
# 5   0.0     0        Q   8.4583
# 6  54.0   E46        S  51.8625
# 7   2.0     0        S  21.0750
# 8  27.0     0        S  11.1333
# 9  14.0     0        C  30.0708
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
# 5                                   Moran, Mr. James      0            6
# 6                            McCarthy, Mr. Timothy J      0            7
# ...

# %%
average_age = df['Age'].mean()  
print(f"Yolcuların yaş ortalaması: {average_age}")
# Out:
# Yolcuların yaş ortalaması: 29.69911764705882

# %%
most_common_class = df['Pclass'].mode()[0]  
print(f"En yaygın bilet sınıfı: {most_common_class}")
# Out:
# En yaygın bilet sınıfı: 3

# %%
survival_rate_by_gender = df.groupby('Sex')['Survived'].mean()
print(survival_rate_by_gender) #erkek 0, kadın 1
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.replace([np.inf, -np.inf], np.nan, inplace=True)
titanic.fillna(0, inplace=True)
df.replace([np.inf, -np.inf], np.nan, inplace=True)

df.fillna(0, inplace=True)
df["Death Rate"] = np.where(df["Survived"] > 0, (1 - df["Survived"]) * 100, 100)

# %%
df.to_csv('temizlenmis_titanic.csv', index=False)
print("Temizlenmiş veri başarıyla kaydedildi: temizlenmis_titanic.csv")
# Out:
# Temizlenmiş veri başarıyla kaydedildi: temizlenmis_titanic.csv

# %%
df_yeni= pd.read_csv("temizlenmis_titanic.csv")
print(df_yeni)
df_yeni.head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
